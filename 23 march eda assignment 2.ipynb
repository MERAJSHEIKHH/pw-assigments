# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
import warnings

warnings.filterwarnings("ignore")

# %%
df=pd.read_csv("amazon.csv")

# %%
df
# Out:
#       product_id                                       product_name  \
# 0     B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1     B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2     B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# 3     B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4     B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
# ...          ...                                                ...
# 1460  B08L7J3T31  Noir Aqua - 5pcs PP Spun Filter + 1 Spanner | ...
# 1461  B01M6453MB  Prestige Delight PRWO Electric Rice Cooker (1 ...
# 1462  B009P2LIL4  Bajaj Majesty RX10 2000 Watts Heat Convector R...
# 1463  B00J5DYCCA  Havells Ventil Air DSP 230mm Exhaust Fan (Pist...
# 1464  B01486F4G6  Borosil Jumbo 1000-Watt Grill Sandwich Maker (...
#
#                                                category discounted_price  \
# 0     Computers&Accessories|Accessories&Peripherals|...             ₹399
# ...

# %%
df.columns
# Out:
# Index(['product_id', 'product_name', 'category', 'discounted_price',
#        'actual_price', 'discount_percentage', 'rating', 'rating_count',
#        'about_product', 'user_id', 'user_name', 'review_id', 'review_title',
#        'review_content', 'img_link', 'product_link'],
#       dtype='object')

# %% [markdown]
# # 1 what is the avg rating in each product category

# %%
df
# Out:
#       product_id                                       product_name  \
# 0     B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1     B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2     B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# 3     B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4     B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
# ...          ...                                                ...
# 1460  B08L7J3T31  Noir Aqua - 5pcs PP Spun Filter + 1 Spanner | ...
# 1461  B01M6453MB  Prestige Delight PRWO Electric Rice Cooker (1 ...
# 1462  B009P2LIL4  Bajaj Majesty RX10 2000 Watts Heat Convector R...
# 1463  B00J5DYCCA  Havells Ventil Air DSP 230mm Exhaust Fan (Pist...
# 1464  B01486F4G6  Borosil Jumbo 1000-Watt Grill Sandwich Maker (...
#
#                                                category discounted_price  \
# 0     Computers&Accessories|Accessories&Peripherals|...             ₹399
# ...

# %%
# what is the ang rating in each product category 

df["category"].unique()[:3]
# Out:
# array(['Computers&Accessories|Accessories&Peripherals|Cables&Accessories|Cables|USBCables',
#        'Computers&Accessories|NetworkingDevices|NetworkAdapters|WirelessUSBAdapters',
#        'Electronics|HomeTheater,TV&Video|Accessories|Cables|HDMICables'],
#       dtype=object)

# %%
# Assuming your column is named 'category'
df['category_first_word'] = df['category'].str.split('|').str[0]

df['category_last_word'] = df['category'].str.split('|').str[-1]
# Display the result
#print(df[['category', 'category_first_word']])

print(df['category_first_word'])
# Out:
# 0       Computers&Accessories
# 1       Computers&Accessories
# 2       Computers&Accessories
# 3       Computers&Accessories
# 4       Computers&Accessories
#                 ...
# 1460             Home&Kitchen
# 1461             Home&Kitchen
# 1462             Home&Kitchen
# 1463             Home&Kitchen
# 1464             Home&Kitchen
# Name: category_first_word, Length: 1465, dtype: object

# %%
df["category_last_word"]
# Out:
# 0                      USBCables
# 1                      USBCables
# 2                      USBCables
# 3                      USBCables
# 4                      USBCables
#                   ...
# 1460    WaterPurifierAccessories
# 1461           Rice&PastaCookers
# 1462              HeatConvectors
# 1463                 ExhaustFans
# 1464              SandwichMakers
# Name: category_last_word, Length: 1465, dtype: object

# %%
df["category_first_word"].unique()
# Out:
# array(['Computers&Accessories', 'Electronics', 'MusicalInstruments',
#        'OfficeProducts', 'Home&Kitchen', 'HomeImprovement', 'Toys&Games',
#        'Car&Motorbike', 'Health&PersonalCare'], dtype=object)

# %%
# Convert the 'rating' column to numeric, forcing errors to NaN
df['rating'] = pd.to_numeric(df['rating'], errors='coerce')

# %%
df.dtypes
# Out:
# product_id              object
# product_name            object
# category                object
# discounted_price        object
# actual_price            object
# discount_percentage     object
# rating                 float64
# rating_count            object
# about_product           object
# user_id                 object
# user_name               object
# review_id               object
# review_title            object
# review_content          object
# img_link                object
# product_link            object
# category_first_word     object
# category_last_word      object
# dtype: object

# %%
df["rating"].isna().sum()
# Out:
# 1

# %%
df.dropna(subset=["rating"],inplace=True)

# %%
df["rating"].isna().sum()
# Out:
# 0

# %%
# Convert the 'rating' column to numeric, forcing errors to NaN
df['rating'] = pd.to_numeric(df['rating'], errors='coerce')

# %%
# Assuming your DataFrame is named 'df' and it contains 'category' and 'rating' columns

# Group by 'category' and calculate the mean of 'rating'
avg_rating_by_category = df.groupby("category_first_word")['rating'].mean().reset_index()

# Display the result
print(avg_rating_by_category)
# Out:
#      category_first_word    rating
# 0          Car&Motorbike  3.800000
# 1  Computers&Accessories  4.154967
# 2            Electronics  4.081749
# 3    Health&PersonalCare  4.000000
# 4           Home&Kitchen  4.040716
# 5        HomeImprovement  4.250000
# 6     MusicalInstruments  3.900000
# 7         OfficeProducts  4.309677
# 8             Toys&Games  4.300000

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming 'avg_rating_by_category' DataFrame is ready
# Create a bar plot to show the average rating by category first word
plt.figure(figsize=(12, 6))

sns.barplot(x='category_first_word', y='rating', data=avg_rating_by_category, palette='viridis')

# Add labels and title
plt.title('Average Rating by Category (First Word)', fontsize=16)
plt.xlabel('Category (First Word)', fontsize=14)
plt.ylabel('Average Rating', fontsize=14)

# Rotate x-axis labels for better readability
plt.xticks(rotation=45)

# Show the plot
plt.show()

# %% [markdown]
# # 2 What are the top rating_count products by category

# %%
df.columns
# Out:
# Index(['product_id', 'product_name', 'category', 'discounted_price',
#        'actual_price', 'discount_percentage', 'rating', 'rating_count',
#        'about_product', 'user_id', 'user_name', 'review_id', 'review_title',
#        'review_content', 'img_link', 'product_link', 'category_first_word',
#        'category_last_word'],
#       dtype='object')

# %%
# Assuming 'category' and 'rating_count' are columns in your DataFrame

# Sort the DataFrame by 'category' and 'rating_count' in descending order
df_sorted = df.sort_values(by=['category_first_word', 'rating_count'], ascending=[True, False])

# Drop duplicates to get the top product for each category
top_products_by_category = df_sorted.drop_duplicates(subset='category', keep='first')

# Select the relevant columns (category, product name, and rating count)
top_products_by_category = top_products_by_category[['category_first_word', 'product_name', 'rating_count']]

# Display the result
print(top_products_by_category)
# Out:
#         category_first_word  \
# 1157          Car&Motorbike
# 32    Computers&Accessories
# 691   Computers&Accessories
# 846   Computers&Accessories
# 810   Computers&Accessories
# ...                     ...
# 850          OfficeProducts
# 808          OfficeProducts
# 948          OfficeProducts
# 757          OfficeProducts
# 924              Toys&Games
#
#                                            product_name rating_count
# 1157  Reffair AX30 [MAX] Portable Air Purifier for C...        1,118
# 32    Zoul USB C 60W Fast Charging 3A 6ft/2M Long Ty...          974
# 691   TP-Link USB Bluetooth Adapter for PC, 5.0 Blue...       95,116
# 846   Anjaney Enterprise Smart Multipurpose Foldable...           93
# 810   Crucial BX500 240GB 3D NAND SATA 6.35 cm (2.5-...       92,925
# ...                                                 ...          ...
# 850      Pentonic Multicolor Ball Point Pen, Pack of 10        4,308
# ...

# %%
import pandas as pd

# Assuming your DataFrame is named 'df' and it has 'category', 'product_name', and 'rating_count' columns

# Sort the DataFrame by 'category' and 'rating_count' in descending order
df_sorted = df.sort_values(by=['category_first_word', 'rating_count'], ascending=[True, False])

# Drop duplicates to keep the top product in each category based on rating count
top_products_by_category = df_sorted.drop_duplicates(subset='category_first_word', keep='first')

# Select only the relevant columns: 'category', 'product_name', and 'rating_count'
top_products_by_category = top_products_by_category[['category', 'product_name', 'rating_count',"category_first_word","category_last_word"]]

# Display the top products by category
print(top_products_by_category)
# Out:
#                                                category  \
# 1157  Car&Motorbike|CarAccessories|InteriorAccessori...
# 32    Computers&Accessories|Accessories&Peripherals|...
# 750   Electronics|GeneralPurposeBatteries&BatteryCha...
# 1247  Health&PersonalCare|HomeMedicalSupplies&Equipm...
# 1059  Home&Kitchen|Kitchen&HomeAppliances|SmallKitch...
# 982           HomeImprovement|Electrical|CordManagement
# 613            MusicalInstruments|Microphones|Condenser
# 702   OfficeProducts|OfficePaperProducts|Paper|Stati...
# 924   Toys&Games|Arts&Crafts|Drawing&PaintingSupplie...
#
#                                            product_name rating_count  \
# 1157  Reffair AX30 [MAX] Portable Air Purifier for C...        1,118
# 32    Zoul USB C 60W Fast Charging 3A 6ft/2M Long Ty...          974
# 750        Eveready Red 1012 AAA Batteries - Pack of 10          989
# 1247  Dr Trust Electronic Kitchen Digital Scale Weig...        3,663
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Set the figure size
plt.figure(figsize=(10, 6))

# Create a barplot for the top products by rating count for each category
sns.barplot(x='category_last_word', y='rating_count', data=top_products_by_category, palette='Blues_d')

# Rotate the x-axis labels for better readability
plt.xticks(rotation=45)

# Add labels and title
plt.title('Top Products by Rating Count in Each Category', fontsize=16)
plt.xlabel('Category', fontsize=14)
plt.ylabel('Rating Count', fontsize=14)

# Show the plot
plt.show()

# %% [markdown]
# # 3  What is the distribution of discounted prices vs. actual prices

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Set the figure size
plt.figure(figsize=(12, 6))


df1=df[["actual_price","discounted_price"]]
# Create a DataFrame for plotting
melted_df = df1.melt(value_vars=['actual_price', 'discounted_price'], var_name='Price Type', value_name='Price')


# Create a box plot with transparency
sns.boxplot(
    x='Price Type',
    y='Price',
    #data=melted_df,
    data=melted_df,
    boxprops=dict(facecolor='blue', alpha=0.3),  # Set box color and transparency
    whiskerprops=dict(color='blue', alpha=0.5),  # Set whisker color and transparency
    medianprops=dict(color='red', alpha=0.8),    # Set median color and transparency
    capprops=dict(color='blue', alpha=0.5),      # Set cap color and transparency
    flierprops=dict(markerfacecolor='blue', marker='o', alpha=0.5)  # Set outlier color and transparency
)

# Add labels and title
plt.title('Box Plot of Actual Prices vs. Discounted Prices', fontsize=16)
plt.xlabel('Price Type', fontsize=14)
plt.ylabel('Price', fontsize=14)

# Show the plot
plt.show()

# %%
# discounted price is much lower then the actual price

# %%
df
# Out:
#       product_id                                       product_name  \
# 0     B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1     B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2     B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# 3     B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4     B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
# ...          ...                                                ...
# 1460  B08L7J3T31  Noir Aqua - 5pcs PP Spun Filter + 1 Spanner | ...
# 1461  B01M6453MB  Prestige Delight PRWO Electric Rice Cooker (1 ...
# 1462  B009P2LIL4  Bajaj Majesty RX10 2000 Watts Heat Convector R...
# 1463  B00J5DYCCA  Havells Ventil Air DSP 230mm Exhaust Fan (Pist...
# 1464  B01486F4G6  Borosil Jumbo 1000-Watt Grill Sandwich Maker (...
#
#                                                category discounted_price  \
# 0     Computers&Accessories|Accessories&Peripherals|...             ₹399
# ...

# %% [markdown]
# # 4. How does the average discount percentage vary across categories?

# %%
df["actual_price"]=df["actual_price"].str.replace("₹","")

# %%
df["actual_price"]=df["actual_price"].str.replace(",","")

# %%
df["discounted_price"]=df["discounted_price"].str.replace("₹","")

# %%
df["discounted_price"]=df["discounted_price"].str.replace(",","")

# %%
df["discount_percentage"]=df["discount_percentage"].str.replace("%","")

# %%
df.isnull().sum()
# Out:
# product_id             0
# product_name           0
# category               0
# discounted_price       0
# actual_price           0
# discount_percentage    0
# rating                 0
# rating_count           2
# about_product          0
# user_id                0
# user_name              0
# review_id              0
# review_title           0
# review_content         0
# img_link               0
# product_link           0
# category_first_word    0
# category_last_word     0
# dtype: int64

# %%
df.dtypes
# Out:
# product_id              object
# product_name            object
# category                object
# discounted_price        object
# actual_price            object
# discount_percentage     object
# rating                 float64
# rating_count            object
# about_product           object
# user_id                 object
# user_name               object
# review_id               object
# review_title            object
# review_content          object
# img_link                object
# product_link            object
# category_first_word     object
# category_last_word      object
# dtype: object

# %%
df["actual_price"]=pd.to_numeric(df["actual_price"],errors="coerce")

#
#df['rating'] = pd.to_numeric(df['rating'], errors='coerce')

# %%
df["discounted_price"]=pd.to_numeric(df["discounted_price"],errors="coerce")

# %%
df["discount_percentage"]=pd.to_numeric(df["discount_percentage"],errors="coerce")

# %%
df.isna().sum()
# Out:
# product_id             0
# product_name           0
# category               0
# discounted_price       0
# actual_price           0
# discount_percentage    0
# rating                 0
# rating_count           2
# about_product          0
# user_id                0
# user_name              0
# review_id              0
# review_title           0
# review_content         0
# img_link               0
# product_link           0
# category_first_word    0
# category_last_word     0
# dtype: int64

# %%
# Group by the first word of the category and calculate the average discount percentage
average_discount_by_category_first_word = df.groupby('category_first_word')['discount_percentage'].mean().reset_index()

# Rename the columns for clarity
average_discount_by_category_first_word.columns = ['Category', 'Average Discount Percentage']

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Set the figure size
plt.figure(figsize=(12, 6))

# Create a bar plot for average discount percentage by category first word
sns.barplot(x='Category', y='Average Discount Percentage', data=average_discount_by_category_first_word, palette='viridis')

# Rotate x-axis labels for better readability
plt.xticks(rotation=45)

# Add labels and title
plt.title('Average Discount Percentage by Category (First Word)', fontsize=16)
plt.xlabel('Category (First Word)', fontsize=14)
plt.ylabel('Average Discount Percentage (%)', fontsize=14)

# Show the plot
plt.show()

# %%
# highest no of discount is given on home improvement products and lowest discount is given on toys and games 
# almost 40 % discount is given on every category prodcts except office products and toy and games

# %% [markdown]
# # 5. What are the most popular product names?

# %%
df.columns
# Out:
# Index(['product_id', 'product_name', 'category', 'discounted_price',
#        'actual_price', 'discount_percentage', 'rating', 'rating_count',
#        'about_product', 'user_id', 'user_name', 'review_id', 'review_title',
#        'review_content', 'img_link', 'product_link', 'category_first_word',
#        'category_last_word'],
#       dtype='object')

# %%
import pandas as pd

# Count occurrences of each product name
product_counts = df['product_name'].value_counts().reset_index()
product_counts.columns = ['Product Name', 'Count']

# Display the top products
print(product_counts.head())
# Out:
#                                         Product Name  Count
# 0  Fire-Boltt Ninja Call Pro Plus 1.83" Smart Wat...      5
# 1  Fire-Boltt Phoenix Smart Watch with Bluetooth ...      4
# 2  Wayona Nylon Braided USB to Lightning Fast Cha...      3
# 3  MI Braided USB Type-C Cable for Charging Adapt...      3
# 4  Amazonbasics Nylon Braided Usb-C To Lightning ...      3

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Set the figure size
plt.figure(figsize=(12, 8))

# Create a bar plot for the most popular product names
sns.barplot(x='Count', y='Product Name', data=product_counts.head(10), palette='viridis')

# Add labels and title
plt.title('Top 10 Most Popular Product Names', fontsize=16)
plt.xlabel('Number of Occurrences', fontsize=14)
plt.ylabel('Product Name', fontsize=14)

# Show the plot
plt.show()

# %%
# top popular product is fire bolt call pro plus

# %%
df.columns
# Out:
# Index(['product_id', 'product_name', 'category', 'discounted_price',
#        'actual_price', 'discount_percentage', 'rating', 'rating_count',
#        'about_product', 'user_id', 'user_name', 'review_id', 'review_title',
#        'review_content', 'img_link', 'product_link', 'category_first_word',
#        'category_last_word'],
#       dtype='object')

# %%
df
# Out:
#       product_id                                       product_name  \
# 0     B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1     B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2     B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# 3     B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4     B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
# ...          ...                                                ...
# 1460  B08L7J3T31  Noir Aqua - 5pcs PP Spun Filter + 1 Spanner | ...
# 1461  B01M6453MB  Prestige Delight PRWO Electric Rice Cooker (1 ...
# 1462  B009P2LIL4  Bajaj Majesty RX10 2000 Watts Heat Convector R...
# 1463  B00J5DYCCA  Havells Ventil Air DSP 230mm Exhaust Fan (Pist...
# 1464  B01486F4G6  Borosil Jumbo 1000-Watt Grill Sandwich Maker (...
#
#                                                category  discounted_price  \
# 0     Computers&Accessories|Accessories&Peripherals|...             399.0
# ...

# %% [markdown]
# # 6. What are the most popular product keywords?

# %%
import pandas as pd

# Sample DataFrame



# Tokenize product names into keywords (you can customize this based on your needs)
df['keywords'] = df['product_name'].str.split(' ')

# %%
from collections import Counter

# Flatten the list of keywords
all_keywords = df['keywords'].explode()

# Count occurrences of each keyword
keyword_counts = Counter(all_keywords)

# Convert to DataFrame for easier manipulation
keyword_counts_df = pd.DataFrame(keyword_counts.items(), columns=['Keyword', 'Count'])

# Sort by count in descending order
keyword_counts_df = keyword_counts_df.sort_values(by='Count', ascending=False).reset_index(drop=True)

# Display the result
print(keyword_counts_df)
# Out:
#       Keyword  Count
# 0        with    715
# 1         for    613
# 2           |    457
# 3           &    431
# 4         USB    342
# ...       ...    ...
# 6433    Tray,      1
# 6434  Ambient      1
# 6435      car      1
# 6436    Bulb,      1
# 6437    Jumbo      1
#
# [6438 rows x 2 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Set the figure size
plt.figure(figsize=(12, 6))

# Create a bar plot for the most popular keywords
sns.barplot(x='Count', y='Keyword', data=keyword_counts_df.head(10), palette='viridis')

# Add labels and title
plt.title('Top 10 Most Popular Product Keywords', fontsize=16)
plt.xlabel('Frequency', fontsize=14)
plt.ylabel('Keyword', fontsize=14)

# Show the plot
plt.show()

# %%
# top most popular keywords are with and for

# %%
df.columns
# Out:
# Index(['product_id', 'product_name', 'category', 'discounted_price',
#        'actual_price', 'discount_percentage', 'rating', 'rating_count',
#        'about_product', 'user_id', 'user_name', 'review_id', 'review_title',
#        'review_content', 'img_link', 'product_link', 'category_first_word',
#        'category_last_word', 'keywords'],
#       dtype='object')

# %% [markdown]
# # 7. What are the most popular product reviews?

# %%
df.columns
# Out:
# Index(['product_id', 'product_name', 'category', 'discounted_price',
#        'actual_price', 'discount_percentage', 'rating', 'rating_count',
#        'about_product', 'user_id', 'user_name', 'review_id', 'review_title',
#        'review_content', 'img_link', 'product_link', 'category_first_word',
#        'category_last_word', 'keywords'],
#       dtype='object')

# %%
import pandas as pd

# Count occurrences of each product name
review_counts = df['review_title'].value_counts().reset_index()
product_counts.columns = ['review_title', 'Count']

# Display the top products
print(review_counts.head())
# Out:
#                                         review_title  count
# 0  Worked on iPhone 7 and didn’t work on XR,Good ...     10
# 1  Satisfied,Charging is really fast,Value for mo...      8
# 2  Phone, camera, heating - works for me, may not...      8
# 3  Good product,Good one,Nice,Really nice product...      7
# 4  A Good Braided Cable for Your Type C Device,Go...      7

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Set the figure size
plt.figure(figsize=(12, 8))

# Create a bar plot for the most popular product names
sns.barplot(x='Count', y='review_title', data=product_counts.head(10), palette='viridis')

# Add labels and title
plt.title('Top 10 Most Popular Product Names', fontsize=16)
plt.xlabel('Number of Occurrences', fontsize=14)
plt.ylabel('Product Name', fontsize=14)

# Show the plot
plt.show()

# %%
# here most popular count product review title is  worked on i phone and didnt work on xr------

# %%
df.columns
# Out:
# Index(['product_id', 'product_name', 'category', 'discounted_price',
#        'actual_price', 'discount_percentage', 'rating', 'rating_count',
#        'about_product', 'user_id', 'user_name', 'review_id', 'review_title',
#        'review_content', 'img_link', 'product_link', 'category_first_word',
#        'category_last_word', 'keywords'],
#       dtype='object')

# %% [markdown]
# # 8. What is the correlation between discounted_price and rating?

# %%
correlation = df['discounted_price'].corr(df['rating'])                                   
print(f'Correlation between discounted_price and rating: {correlation:.2f}')            

# Visualization: Scatter plot
plt.figure(figsize=(8, 6))
sns.scatterplot(x='discounted_price', y='rating', data=df, color='b')

#sns.scatterplot(x='rating ', y='discounted_price', data=df, color='b')    # will not work as assumpted


# Add a trend line (regression line)
sns.regplot(x='discounted_price', y='rating', data=df, scatter=False, color='r')

# Add title and labels
plt.title('Correlation between Discounted Price and Rating')
plt.xlabel('Discounted Price')
plt.ylabel('Rating')

# Display the plot
plt.show()
# Out:
# Correlation between discounted_price and rating: 0.12

# %%
df2=df[['discounted_price','rating']]

correlation_matrix = df2.corr()

# Plot the heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')

# Add title
plt.title('Correlation Matrix')

# Display the plot
plt.show()

# %%
# higher dicount price tends to have slightly higher rating 

#there is a positve relationship 

#if discount price will increse 12v% chance of increae in rating

# %%
df
# Out:
#       product_id                                       product_name  \
# 0     B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1     B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2     B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# 3     B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4     B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
# ...          ...                                                ...
# 1460  B08L7J3T31  Noir Aqua - 5pcs PP Spun Filter + 1 Spanner | ...
# 1461  B01M6453MB  Prestige Delight PRWO Electric Rice Cooker (1 ...
# 1462  B009P2LIL4  Bajaj Majesty RX10 2000 Watts Heat Convector R...
# 1463  B00J5DYCCA  Havells Ventil Air DSP 230mm Exhaust Fan (Pist...
# 1464  B01486F4G6  Borosil Jumbo 1000-Watt Grill Sandwich Maker (...
#
#                                                category  discounted_price  \
# 0     Computers&Accessories|Accessories&Peripherals|...             399.0
# ...

# %% [markdown]
# # 9. What are the Top 5 categories based on the highest ratings?

# %%
 #Group by 'category' and calculate the average rating
category_ratings = df.groupby('category')['rating'].mean().reset_index()

# Sort the categories by rating in descending order
category_ratings = category_ratings.sort_values(by='rating', ascending=False)

# Select the Top 5 categories
top_5_categories = category_ratings.head(5)

# Plot the Top 5 categories by average rating

plt.figure(figsize=(5,5))
sns.barplot(x='rating', y='category', data=top_5_categories, palette='Blues_d')

# Add title and labels
plt.title('Top 5 Categories Based on Highest Ratings')
plt.xlabel('Average Rating')
plt.ylabel('Category')

# Display the plot
plt.show()

# %%
# here u can see that the computer and accessary category have the higest no of rationg espacially in table product

# %% [markdown]
# # 10. Identify any potential areas for improvement or optimization based on the data analysis

# %% [markdown]
# 1. Improve Rating for Specific Product Categories:
# Observation: If certain product categories (e.g., chargers or cables) have lower average ratings, this indicates areas where customer satisfaction might be lacking.
# Action: Focus on improving the quality, features, or customer service for products in these categories. Customer feedback or reviews may provide insight into specific issues (e.g., durability, functionality, or price-performance ratio).
# 2. Correlation Between Discounted Price and Ratings:
# Observation: The correlation between discounted_price and rating is weak (0.12). This suggests that price reductions alone are not significantly influencing higher ratings.
# Action: Instead of relying solely on discounts to improve customer perception, consider improving product quality, offering better after-sales service, or bundling products with complementary items to enhance overall customer experience.
# 3. Enhance Marketing for Top-Rated Products:
# Observation: Top 5 categories or products with the highest ratings (e.g., smartwatches) indicate strong customer satisfaction.
# Action: Focus marketing efforts on these highly rated products to increase sales. Highlight positive reviews and ratings in promotional materials and product listings to build trust and attract more customers.
# 4. Address Poor-Performing Products or Categories:
# Observation: Categories or products with consistently lower ratings (e.g., products with an average rating below 3.5) may be dragging down overall performance.
# Action: Investigate why these products are underperforming by analyzing detailed reviews and user feedback. If necessary, consider product redesign, improving manufacturing quality, or even discontinuing low-rated products to maintain overall brand reputation.
# 5. Optimize Product Features Based on Reviews:
# Observation: Analyzing the most popular reviews can reveal common themes, complaints, or praises regarding product features.
# Action: Use this feedback to refine product features. For instance, if multiple reviews of a product mention short battery life or poor connectivity, these are areas that should be addressed in future versions or updates.
# 6. Use Ratings to Predict Trends:
# Observation: If there’s a trend where certain products (e.g., newer models of smartwatches) consistently get higher ratings, you can predict future demand.
# Action: Focus product development and inventory management on these high-demand categories. Use customer feedback and ratings trends to shape product design and release schedules.
# 7. Improving Product Description and Content Quality:
# Observation: Products with good content in reviews (e.g., more detailed and well-received reviews) tend to be more popular.
# Action: Improve product descriptions, images, and videos on your platform to give customers more confidence in their purchases. Also, encourage customers to leave detailed and helpful reviews to build trust and inform future buyers.
# 8. Further Analyze the Relationship Between Price and Rating:
# Observation: The weak correlation between discounted_price and rating could be explored more deeply to understand the relationship.
# Action: Segment the data by product type or price range to see if the correlation varies across categories. For example, luxury products may show a stronger correlation between price and rating than budget items.
# 9. Refine Discount Strategy:
# Observation: Since discounted prices don't have a strong influence on ratings, as indicated by the correlation value, the current discount strategy might need refinement.
# Action: Use personalized discounts or promotional strategies targeting specific customer segments rather than across-the-board price cuts. Focus on value-added services like extended warranties or freebies instead of just reducing prices.

# %% [markdown]
# # spotify datasets

# %% [markdown]
# # 1.Load the dataframe and ensure data quality by checking for missing values and duplicate rows.Handle missing values and remove duplicate rows if necessary.

# %%
df=pd.read_csv("spotify.csv")

# %%
df.dtypes
# Out:
# Artist           object
# Track Name       object
# Popularity        int64
# Duration (ms)     int64
# Track ID         object
# dtype: object

# %%
df
# Out:
#              Artist                                         Track Name  \
# 0             Drake            Rich Baby Daddy (feat. Sexyy Red & SZA)
# 1             Drake                                          One Dance
# 2             Drake                                 IDGAF (feat. Yeat)
# 3             Drake               First Person Shooter (feat. J. Cole)
# 4             Drake                      Jimmy Cooks (feat. 21 Savage)
# ..              ...                                                ...
# 435  French Montana                                    Splash Brothers
# 436         Fat Joe                     All The Way Up (feat. Infared)
# 437       A$AP Ferg  Work REMIX (feat. A$AP Rocky, French Montana, ...
# 438           Diddy                Another One Of Me (feat. 21 Savage)
# 439       Rick Ross                                       Stay Schemin
#
#      Popularity  Duration (ms)                Track ID
# 0            92         319191  1yeB8MUNeLo9Ek1UEpsyz6
# ...

# %%
df.isnull().sum()
# Out:
# Artist           0
# Track Name       0
# Popularity       0
# Duration (ms)    0
# Track ID         0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 27

# %%
df.drop_duplicates(inplace=True)

# %% [markdown]
# # 2.What is the distribution of popularity among the tracks in the dataset? Visualize it using a histogram.

# %%
#df["Track Name"].unique()

# %%
plt.figure(figsize=(10, 6))

sns.histplot(df["Popularity"],kde= True,bins=20,color='blue')
plt.title('Distribution of Track Popularity', fontsize=16)
plt.xlabel('Popularity', fontsize=14)
plt.ylabel('Frequency', fontsize=14)
plt.show()

# %%
# higest no of popularity is 80

# and the lowest is 30 to 35

# %% [markdown]
# # 3.Is there any relationship between the popularity and the duration of tracks? Explore this using a scatter plot.

# %%
# Assuming 'duration_ms' is in milliseconds, convert it to minutes
df['duration_minutes'] = df["Duration (ms)"] / 60000

# %%
# Scatter plot with regression line
sns.lmplot(x='duration_minutes', y='Popularity', data=df,height=8,scatter_kws={'alpha':0.5},line_kws={"color": "red"})

#sns.regplot(x='duration_minutes', y='Popularity', data=df, scatter_kws={'alpha':0.5}, line_kws={"color": "red"})

# %% [markdown]
# most of the track have 3 to 4 min of duration
#
# very small no of track have duration of 6 to 8 min

# %% [markdown]
# # 4.Which artist has the highest number of tracks in the dataset? Display the count of tracks for each artist using a countplot.

# %%
import seaborn as sns
import matplotlib.pyplot as plt


plt.figure(figsize=(12, 8))

# Count the number of tracks for each artist
artist_track_count = df['Artist'].value_counts().reset_index()
#artist_track_count.columns = ['Artist', 'count']

# Get the top 10 artists by track count
top_artists = artist_track_count.head(10)

# Filter the original DataFrame to include only the top artists
filtered_df = df[df['Artist'].isin(top_artists['Artist'])]                                       



sns.countplot(y='Artist', data=filtered_df, palette='coolwarm')

plt.title('Top 10 Artists by Number of Tracks', fontsize=16)
plt.xlabel('Number of Tracks', fontsize=14)
plt.ylabel('Artist', fontsize=14)
plt.yticks(rotation=30)
# Show the plot
plt.show()

# %% [markdown]
# drake has the highest no of track  about 16
#
# mostly have 10 no of track

# %% [markdown]
# # 5.What are the top 5 least popular tracks in the dataset? Provide the artist name and track name for each.

# %%
import seaborn as sns
import matplotlib.pyplot as plt


plt.figure(figsize=(12, 8))

# Count the number of tracks for each artist
artist_track_count = df['Artist'].value_counts().reset_index()
#artist_track_count.columns = ['Artist', 'count']

# Get the top 10 artists by track count
top_artists = artist_track_count.tail(5)

# Filter the original DataFrame to include only the top artists
filtered_df = df[df['Artist'].isin(top_artists['Artist'])]                                       



sns.countplot(y='Artist', data=filtered_df, palette='coolwarm')

plt.title('Top 10 Artists by Number of Tracks', fontsize=16)
plt.xlabel('Number of Tracks', fontsize=14)
plt.ylabel('Artist', fontsize=14)
plt.yticks(rotation=30)
# Show the plot
plt.show()

# %% [markdown]
# # 6.Among the top 5 most popular artists, which artist has the highest popularity on average?Calculate and display the average popularity for each artist.

# %%
import pandas as pd




artist_track_count = df['Artist'].value_counts().reset_index()
#artist_track_count.columns = ['Artist', 'Track_Count']

top_artists = artist_track_count.head(5)

# Step 2: Filter the original DataFrame to include only the top 5 artists
filtered_df = df[df['Artist'].isin(top_artists['Artist'])]


# Step 3: Calculate the average popularity for each artist
average_popularity = filtered_df.groupby('Artist')['Popularity'].mean().reset_index()
average_popularity.columns = ['Artist', 'Average_Popularity']

# Merge with top_artists DataFrame to get track count along with average popularity
result_df = pd.merge(top_artists, average_popularity, on='Artist')

# Step 4: Display the results
print(result_df)

# Optional: Plot the average popularity of the top 5 a rtists
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
sns.barplot(x='Artist', y='Average_Popularity', data=result_df, palette='coolwarm')
plt.title('Average Popularity of Top 5 Most Popular Artists', fontsize=16)
plt.xlabel('Artist', fontsize=14)
plt.ylabel('Average Popularity', fontsize=14)
plt.show()
# Out:
#       Artist  count  Average_Popularity
# 0      Drake     17           82.882353
# 1     Eminem     11           83.636364
# 2   Flo Rida     10           78.000000
# 3   Ludacris     10           63.000000
# 4  Timbaland     10           69.000000

# %%
# drake has the highest avg popularity  which is about 82 

#ludacris has the lowest avg popularity which is 63

# %%
df.columns
# Out:
# Index(['Artist', 'Track Name', 'Popularity', 'Duration (ms)', 'Track ID',
#        'duration_minutes'],
#       dtype='object')

# %% [markdown]
# # 7.For the top 5 most popular artists, what are their most popular tracks? List the track name for each artist.

# %%
import pandas as pd

# Sample DataFrame (df should have columns 'Artist', 'Track', and 'Popularity')

# Step 1: Compute average popularity for each artist
average_popularity = df.groupby('Artist')['Popularity'].mean().reset_index()

# Step 2: Sort artists by average popularity and get the top 5
top_artists = average_popularity.sort_values(by='Popularity', ascending=False).head(5)

# Step 3: Filter the original DataFrame to include only tracks from the top 5 artists
top_artists_names = top_artists['Artist'].tolist()  # Get a list of top 5 artist names
top_tracks = df[df['Artist'].isin(top_artists_names)]

# Step 4: Find the most popular track for each artist
most_popular_tracks = top_tracks.loc[top_tracks.groupby('Artist')["Track Name"].idxmax()]



# Display the most popular track for each of the top 5 artists
print(most_popular_tracks1[['Artist', 'Track Name', 'Popularity']])
# Out:
#            Artist                    Track Name  Popularity
# 200  David Guetta            Baby Don't Hurt Me          87
# 33   Travis Scott                    goosebumps          89
# 241        Trueno  Mamichula - con Nicki Nicole          89
# 140         cassö                         Prada          92
# 269            ¥$                      VULTURES          80

# %% [markdown]
# # 8.Visualize relationships between multiple numerical variables simultaneously using a pair plot.

# %%
plt.figure(figsize=(10, 8))

sns.pairplot(df, )  


plt.suptitle('Pair Plot of Numerical Variables', y=1.02, fontsize=16)

# Show the plot
plt.show()

# %% [markdown]
# # 9.Does the duration of tracks vary significantly across different artists?Explore this visually using a box plot or violin plot.

# %%
df.columns
# Out:
# Index(['Artist', 'Track Name', 'Popularity', 'Duration (ms)', 'Track ID',
#        'duration_minutes'],
#       dtype='object')

# %%
df['duration_minutes'] = df["Duration (ms)"] / 60000

# Set the figure size
plt.figure(figsize=(5,6))

# Create a box plot for track duration by artist
sns.boxplot(x='Artist', y='duration_minutes', data=df, palette='Set2')

# Add labels and title
plt.title('Distribution of Track Duration Across Different Artists', fontsize=16)
plt.xlabel('Artist', fontsize=14)
plt.ylabel('Track Duration(minutes)', fontsize=14)

# Rotate x-axis labels for better readability
plt.xticks(rotation=45)

# Show the plot
plt.show()

# %%
yes the duration of tracks vary significantly across different artists

# %% [markdown]
# # 10.How does the distribution of track popularity vary for different artists?Visualize this using a swarm plot or a violin plot.

# %%
# Set the figure size
plt.figure(figsize=(14, 8))

# Create a violin plot to visualize the distribution of track popularity across different artists
sns.violinplot(x='Artist', y='Popularity', data=df, palette='Set2')

# Add labels and title
plt.title('Distribution of Track Popularity by Artist', fontsize=16)
plt.xlabel('Artist', fontsize=14)
plt.ylabel('Popularity', fontsize=14)

# Rotate x-axis labels for better readability if there are many artists
plt.xticks(rotation=45)

# Show the plot
plt.show()

# %%
# yes the distribution of track popularity vary for different artists
